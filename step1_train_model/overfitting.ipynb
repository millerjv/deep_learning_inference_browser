# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))

# %matplotlib notebook
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import settings
import interactive_overfitting

import importlib
importlib.reload(settings)
importlib.reload(interactive_overfitting)
# Out:
# <module 'interactive_overfitting' from '/Users/200005014/Projects/deep_learning_inference_browser/step1_train_model/interactive_overfitting.py'>

# %%
model = "brainWholeTumor-mobile-out=2-balanced=True-bn=False"
#model = "brainWholeTumor-mobile-balanced=True-bn=True-bnafter"
for model_number in range(9,10) :
    model_fn = '{}__epoch={:03d}.hdf5'.format(model, model_number)
    interactive_overfitting.interactive_overfitting(settings.OUT_PATH, settings.IMG_ROWS/settings.RESCALE_FACTOR, settings.IMG_COLS/settings.RESCALE_FACTOR, settings.IN_CHANNEL_NO, settings.OUT_CHANNEL_NO, model_fn, mode=settings.MODE)
# Out:
# Epsilon 1e-07
# Epsilon 1e-07
# ------------------------------
# Loading and preprocessing test data...
# ------------------------------
# ----------  Whole tumor ----------
# Number of test images is  1364
# ------------------------------
# Creating and compiling model...
# ------------------------------
# ------------------------------
# Mobile U-net: in=1, out=2, balanced=True, batch_normalization=False, batch_normalization_after=False
# ------------------------------
# Last layer activation <function softmax at 0x1193779d8>
# ------------------------------
# Loading saved weights...
# ------------------------------
# ------------------------------
# Predict on test image: (not necessary to call predict) 18
# ------------------------------
# Scoring model on test image:  18
# Scores on original wrt gt ['loss', 'acc', 'dice_coef']: [0.4132835268974304, 0.9490966796875, 0.6614747047424316]
# ------------------------------
# Creating guided perturbation pipeline ...
# ...

# %%
b=1
x = 4
a[x - math.floor(b/2) : x + math.floor(b/2) + 1]
# Out:
# [5]

# %%
for s in test_bg_strokes[84]:
    print(s)
# Out:
# [[52, 97], [3, 3]]
# [[53, 98], [3, 3]]
# [[55, 99], [3, 3]]
# [[60, 100], [3, 3]]

# %%
test_bg_strokes[84]
# Out:
# [[[52, 97], [3, 3]],
#  [[53, 98], [3, 3]],
#  [[55, 99], [3, 3]],
#  [[60, 100], [3, 3]]]

# %%
test_fg_strokes = {}
test_fg_strokes[31] = []
test_fg_strokes[57] = [[[51,74], [3,3]], [[75,71], [3,3]]]
test_fg_strokes[84] = [[[81,111], [1,1]]]

test_bg_strokes = {}
test_bg_strokes[31] = []
test_bg_strokes[57] = [[[70,73], [3,3]], [[56,75], [3,3]]]
test_bg_strokes[84] = [[[52, 97], [3,3]], [[53,98], [3,3]], [[55,99], [3,3]], [[60, 100], [3,3]]]
